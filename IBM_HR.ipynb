# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("HR-Employee-Attrition.csv")

# %%
df
# Out:
#        Age Attrition     BusinessTravel  DailyRate              Department  \
# 0       41       Yes      Travel_Rarely       1102                   Sales
# 1       49        No  Travel_Frequently        279  Research & Development
# 2       37       Yes      Travel_Rarely       1373  Research & Development
# 3       33        No  Travel_Frequently       1392  Research & Development
# 4       27        No      Travel_Rarely        591  Research & Development
# ...    ...       ...                ...        ...                     ...
# 10465   57        No  Travel_Frequently        842         Human Resources
# 10466   23        No  Travel_Frequently        530                   Sales
# 10467   21        No      Travel_Rarely        451                   Sales
# 10468   43        No  Travel_Frequently        209         Human Resources
# 10469   47        No         Non-Travel       1149         Human Resources
#
#        DistanceFromHome  Education    EducationField  EmployeeCount  \
# 0                     1          2     Life Sciences              1
# 1                     8          1     Life Sciences              1
# 2                     2          2             Other              1
# 3                     3          4     Life Sciences              1
# 4                     2          1           Medical              1
# ...                 ...        ...               ...            ...
# 10465                23          3             Other              1
# 10466                11          5     Life Sciences              1
# 10467                 4          4  Technical Degree              1
# 10468                 7          5     Life Sciences              1
# 10469                23          3           Medical              1
#
#        EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0                   1  ...                         1            80
# 1                   2  ...                         4            80
# 2                   4  ...                         2            80
# 3                   5  ...                         3            80
# 4                   7  ...                         4            80
# ...               ...  ...                       ...           ...
# 10465            2048  ...                         1            80
# 10466             664  ...                         4            80
# 10467              32  ...                         3            80
# 10468             323  ...                         2            80
# 10469             390  ...                         3            80
#
#        StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                     0                  8                      0
# 1                     1                 10                      3
# 2                     0                  7                      3
# 3                     0                  8                      3
# 4                     1                  6                      3
# ...                 ...                ...                    ...
# 10465                 0                 33                      3
# 10466                 1                 33                      3
# 10467                 0                 40                      2
# 10468                 0                 18                      4
# 10469                 3                 40                      0
#
#       WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0                   1               6                  4
# 1                   3              10                  7
# 2                   3               0                  0
# 3                   3               8                  7
# 4                   3               2                  2
# ...               ...             ...                ...
# 10465               2              28                  1
# 10466               3              20                 16
# 10467               3              21                  5
# 10468               4              33                  8
# 10469               2               1                 14
#
#        YearsSinceLastPromotion  YearsWithCurrManager
# 0                            0                     5
# 1                            1                     7
# 2                            0                     0
# 3                            3                     0
# 4                            2                     2
# ...                        ...                   ...
# 10465                       11                     0
# 10466                       13                     2
# 10467                       14                    10
# 10468                       11                    11
# 10469                       10                    13
#
# [10470 rows x 35 columns]

# %%
df.shape
# Out:
# (10470, 35)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10470 entries, 0 to 10469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       10470 non-null  int64
#  1   Attrition                 10470 non-null  object
#  2   BusinessTravel            10470 non-null  object
#  3   DailyRate                 10470 non-null  int64
#  4   Department                10470 non-null  object
#  5   DistanceFromHome          10470 non-null  int64
#  6   Education                 10470 non-null  int64
#  7   EducationField            10470 non-null  object
#  8   EmployeeCount             10470 non-null  int64
#  9   EmployeeNumber            10470 non-null  int64
#  10  EnvironmentSatisfaction   10470 non-null  int64
#  11  Gender                    10470 non-null  object
#  12  HourlyRate                10470 non-null  int64
#  13  JobInvolvement            10470 non-null  int64
#  14  JobLevel                  10470 non-null  int64
#  15  JobRole                   10470 non-null  object
#  16  JobSatisfaction           10470 non-null  int64
#  17  MaritalStatus             10470 non-null  object
#  18  MonthlyIncome             10470 non-null  int64
#  19  MonthlyRate               10470 non-null  int64
#  20  NumCompaniesWorked        10470 non-null  int64
#  21  Over18                    10470 non-null  object
#  22  OverTime                  10470 non-null  object
#  23  PercentSalaryHike         10470 non-null  int64
#  24  PerformanceRating         10470 non-null  int64
#  25  RelationshipSatisfaction  10470 non-null  int64
#  26  StandardHours             10470 non-null  int64
#  27  StockOptionLevel          10470 non-null  int64
#  28  TotalWorkingYears         10470 non-null  int64
#  29  TrainingTimesLastYear     10470 non-null  int64
#  30  WorkLifeBalance           10470 non-null  int64
#  31  YearsAtCompany            10470 non-null  int64
#  32  YearsInCurrentRole        10470 non-null  int64
#  33  YearsSinceLastPromotion   10470 non-null  int64
#  34  YearsWithCurrManager      10470 non-null  int64
# dtypes: int64(26), object(9)
# memory usage: 2.8+ MB

# %%
pd.set_option('display.max_columns',None)
df.describe(include='all')
# Out:
#                  Age Attrition BusinessTravel     DailyRate  \
# count   10470.000000     10470          10470  10470.000000
# unique           NaN         2              3           NaN
# top              NaN       Yes  Travel_Rarely           NaN
# freq             NaN      5637           4046           NaN
# mean       38.682521       NaN            NaN    801.894938
# std        12.071668       NaN            NaN    405.856260
# min        18.000000       NaN            NaN    102.000000
# 25%        29.000000       NaN            NaN    453.000000
# 50%        38.000000       NaN            NaN    801.000000
# 75%        49.000000       NaN            NaN   1155.000000
# max        60.000000       NaN            NaN   1499.000000
#
#                     Department  DistanceFromHome     Education EducationField  \
# count                    10470      10470.000000  10470.000000          10470
# unique                       3               NaN           NaN              6
# top     Research & Development               NaN           NaN  Life Sciences
# freq                      3969               NaN           NaN           2118
# mean                       NaN         14.236581      2.993983            NaN
# std                        NaN          8.580306      1.379704            NaN
# min                        NaN          1.000000      1.000000            NaN
# 25%                        NaN          7.000000      2.000000            NaN
# 50%                        NaN         14.000000      3.000000            NaN
# 75%                        NaN         22.000000      4.000000            NaN
# max                        NaN         29.000000      5.000000            NaN
#
#         EmployeeCount  EmployeeNumber  EnvironmentSatisfaction Gender  \
# count         10470.0    10470.000000             10470.000000  10470
# unique            NaN             NaN                      NaN      2
# top               NaN             NaN                      NaN   Male
# freq              NaN             NaN                      NaN   5371
# mean              1.0     1044.755683                 2.525883    NaN
# std               0.0      597.664016                 1.119922    NaN
# min               1.0        1.000000                 1.000000    NaN
# 25%               1.0      526.000000                 2.000000    NaN
# 50%               1.0     1052.500000                 3.000000    NaN
# 75%               1.0     1557.750000                 4.000000    NaN
# max               1.0     2068.000000                 4.000000    NaN
#
#           HourlyRate  JobInvolvement      JobLevel             JobRole  \
# count   10470.000000    10470.000000  10470.000000               10470
# unique           NaN             NaN           NaN                   9
# top              NaN             NaN           NaN  Research Scientist
# freq             NaN             NaN           NaN                1325
# mean       65.230946        2.538204      2.855778                 NaN
# std        20.499740        1.071796      1.412532                 NaN
# min        30.000000        1.000000      1.000000                 NaN
# 25%        47.000000        2.000000      2.000000                 NaN
# 50%        65.000000        3.000000      3.000000                 NaN
# 75%        83.000000        3.000000      4.000000                 NaN
# max       100.000000        4.000000      5.000000                 NaN
#
#         JobSatisfaction MaritalStatus  MonthlyIncome   MonthlyRate  \
# count      10470.000000         10470   10470.000000  10470.000000
# unique              NaN             3            NaN           NaN
# top                 NaN       Married            NaN           NaN
# freq                NaN          3699            NaN           NaN
# mean           2.542980           NaN    9978.236294  14429.164279
# std            1.113493           NaN    5541.216917   7168.118638
# min            1.000000           NaN    1009.000000   2094.000000
# 25%            2.000000           NaN    5047.500000   8247.500000
# 50%            3.000000           NaN    9613.500000  14360.500000
# 75%            4.000000           NaN   14814.750000  20618.750000
# max            4.000000           NaN   19999.000000  26999.000000
#
#         NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# count         10470.000000  10470    10470       10470.000000
# unique                 NaN      1        2                NaN
# top                    NaN      Y       No                NaN
# freq                   NaN  10470     5677                NaN
# mean              4.266476    NaN      NaN          17.625024
# std               2.877419    NaN      NaN           4.348904
# min               0.000000    NaN      NaN          11.000000
# 25%               2.000000    NaN      NaN          14.000000
# 50%               4.000000    NaN      NaN          17.000000
# 75%               7.000000    NaN      NaN          21.000000
# max               9.000000    NaN      NaN          25.000000
#
#         PerformanceRating  RelationshipSatisfaction  StandardHours  \
# count        10470.000000              10470.000000        10470.0
# unique                NaN                       NaN            NaN
# top                   NaN                       NaN            NaN
# freq                  NaN                       NaN            NaN
# mean             3.447373                  2.514327           80.0
# std              0.497246                  1.108040            0.0
# min              3.000000                  1.000000           80.0
# 25%              3.000000                  2.000000           80.0
# 50%              3.000000                  3.000000           80.0
# 75%              4.000000                  3.000000           80.0
# max              4.000000                  4.000000           80.0
#
#         StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# count       10470.000000       10470.000000           10470.000000
# unique               NaN                NaN                    NaN
# top                  NaN                NaN                    NaN
# freq                 NaN                NaN                    NaN
# mean            1.399236          18.751767               2.987966
# std             1.113366          11.759067               1.920785
# min             0.000000           0.000000               0.000000
# 25%             0.000000           8.250000               1.000000
# 50%             1.000000          18.000000               3.000000
# 75%             2.000000          29.000000               5.000000
# max             3.000000          40.000000               6.000000
#
#         WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# count      10470.000000    10470.000000        10470.000000
# unique              NaN             NaN                 NaN
# top                 NaN             NaN                 NaN
# freq                NaN             NaN                 NaN
# mean           2.545081       18.038395            8.367431
# std            1.077662       12.082882            5.535818
# min            1.000000        0.000000            0.000000
# 25%            2.000000        7.000000            3.000000
# 50%            3.000000       17.000000            8.000000
# 75%            3.000000       29.000000           13.000000
# max            4.000000       40.000000           18.000000
#
#         YearsSinceLastPromotion  YearsWithCurrManager
# count              10470.000000          10470.000000
# unique                      NaN                   NaN
# top                         NaN                   NaN
# freq                        NaN                   NaN
# mean                   6.795702              7.892932
# std                    4.806823              5.239775
# min                    0.000000              0.000000
# 25%                    2.000000              3.000000
# 50%                    7.000000              8.000000
# 75%                   11.000000             12.000000
# max                   15.000000             17.000000

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
columns_to_drop=['EmployeeCount','StandardHours','Over18','EmployeeNumber']
df.drop(columns=columns_to_drop,axis=1,inplace=True)

# %%
sns.set(style="whitegrid")
sns.countplot(x='Attrition',data=df)
plt.title('Attrition Count')
plt.show()

# %%
cat_cols=['Gender','Department','BusinessTravel','JobRole','MaritalStatus']
for col in cat_cols:
    plt.figure(figsize=(8,4))
    sns.countplot(x=col,hue='Attrition',data=df)
    plt.title(f'{col} vs Attrition')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %%
num_cols=['Age','MonthlyIncome','TotalWorkingYears','YearsAtCompany']
for col in num_cols:
    plt.figure(figsize=(6,4))
    sns.boxplot(x='Attrition',y=col,data=df)
    plt.title(f'{col} Distribution by Attrition')
    plt.tight_layout()
    plt.show()

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(numeric_only=True),annot=True,fmt='.2f',cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
selected_features=['Age','MonthlyIncome','YearsAtCompany','Attrition']
sns.pairplot(df[selected_features],hue='Attrition')
plt.suptitle('Pairplot of Selected Features',y=1.02)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.violinplot(x='JobRole',y='MonthlyIncome',hue='Attrition',data=df,split=True)
plt.xticks(rotation=45)
plt.title('Monthly Income Distribution by Job Role and Attrition')
plt.tight_layout()
plt.show()

# %%
pivot_table=df.pivot_table(values='MonthlyIncome',index='JobRole',columns='Attrition',aggfunc='mean')
plt.figure(figsize=(10,6))
sns.heatmap(pivot_table,annot=True,fmt=".0f",cmap="YlGnBu")
plt.title("Average Monthly Income by JobRole and Attrition")
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder,StandardScaler
df_encoded=df.copy()
le=LabelEncoder()
for col in df_encoded.select_dtypes(include='object').columns:
    df_encoded[col]=le.fit_transform(df_encoded[col])

# %%
x=df_encoded.drop('Attrition',axis=1)
y=df_encoded['Attrition']

# %%
scaler=StandardScaler()
x[x.select_dtypes(include=['int64','float64']).columns]=scaler.fit_transform(x.select_dtypes(include=['int64','float64']))

# %%
from imblearn.over_sampling import SMOTE
sm=SMOTE(random_state=42)
x_res,y_res=sm.fit_resample(x,y)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score,roc_auc_score,roc_curve
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %%
x_train,x_test,y_train,y_test=train_test_split(x_res,y_res,test_size=0.2,random_state=42)

# %%
models={
    "Logistic Regression":LogisticRegression(max_iter=1000),
    "Random Forest":RandomForestClassifier(random_state=42),
    "SVM":SVC(probability=True),
    "KNN":KNeighborsClassifier()}

# %%
for name, model in models.items():
    print(f"\n  {name}")
    
    model.fit(x_train, y_train)

    y_pred=model.predict(x_test)
    y_prob=model.predict_proba(x_test)[:,1]
    acc = accuracy_score(y_test, y_pred)
    roc_auc = roc_auc_score(y_test, y_prob)
    
    print(f"  Accuracy        : {acc:.4f}")
    print(f"  ROC AUC Score   : {roc_auc:.4f}")
    print(f"  Confusion Matrix:\n{confusion_matrix(y_test, y_pred)}")
    print(f"  Classification Report:\n{classification_report(y_test, y_pred)}")
# Out:
#   Logistic Regression
#   Accuracy        : 0.5818
#   ROC AUC Score   : 0.6246
#   Confusion Matrix:
# [[606 488]
#  [455 706]]
#   Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.57      0.55      0.56      1094
#            1       0.59      0.61      0.60      1161
#
#     accuracy                           0.58      2255
#    macro avg       0.58      0.58      0.58      2255
# weighted avg       0.58      0.58      0.58      2255
#
#
#   Random Forest
#   Accuracy        : 0.6275
#   ROC AUC Score   : 0.6723
#   Confusion Matrix:
# [[564 530]
#  [310 851]]
#   Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.65      0.52      0.57      1094
#            1       0.62      0.73      0.67      1161
#
#     accuracy                           0.63      2255
#    macro avg       0.63      0.62      0.62      2255
# weighted avg       0.63      0.63      0.62      2255
#
#
#   SVM
#   Accuracy        : 0.6173
#   ROC AUC Score   : 0.6403
#   Confusion Matrix:
# [[544 550]
#  [313 848]]
#   Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.63      0.50      0.56      1094
#            1       0.61      0.73      0.66      1161
#
#     accuracy                           0.62      2255
#    macro avg       0.62      0.61      0.61      2255
# weighted avg       0.62      0.62      0.61      2255
#
#
#   KNN
#   Accuracy        : 0.5729
#   ROC AUC Score   : 0.6256
#   Confusion Matrix:
# [[772 322]
#  [641 520]]
#   Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.55      0.71      0.62      1094
#            1       0.62      0.45      0.52      1161
#
#     accuracy                           0.57      2255
#    macro avg       0.58      0.58      0.57      2255
# weighted avg       0.58      0.57      0.57      2255

# %%
plt.figure(figsize=(10, 6))
for name, model in models.items():
    y_prob = model.predict_proba(x_test)[:, 1]
    fpr, tpr, _ = roc_curve(y_test, y_prob)
    plt.plot(fpr, tpr, label=f"{name} (AUC: {roc_auc_score(y_test, y_prob):.2f})")

plt.plot([0,1],[0,1], "k--")
plt.title("ROC Curve Comparison")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()
